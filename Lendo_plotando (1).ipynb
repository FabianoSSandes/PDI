# %%
# !pip install gdal 
# !pip install rasterio
# !pip install spectral
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# #Tiffile

# %%
import tifffile as tif 
import matplotlib.pyplot as plt
from spectral import imshow

# %%
img = tif.imread('/content/drive/MyDrive/++PESSOAL/Cursos/Mestrado/Curso_PDI_Python/Lendo e plotando/L71221071_07120010720_DN.tif')

# %%
img.shape
# Out:
# (1233, 1520, 6)

# %%
plt.imshow(img[:,:,0])

# %%
plt.imshow(img[:,:,3], cmap='Greys_r')

# %%
imshow(img)
# Out:
# ImageView object:
#   Display bands       :  [0, 3.0, 5]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [40.0, 255.0]
#     G: [12.0, 255.0]
#     B: [1.0, 255.0]

# %%
imshow(img,bands=(2,1,0))
# Out:
# ImageView object:
#   Display bands       :  (2, 1, 0)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [4.0, 255.0]
#     G: [13.0, 255.0]
#     B: [40.0, 255.0]

# %%
imshow(img,bands=(1,0,2))
# Out:
# ImageView object:
#   Display bands       :  (1, 0, 2)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [13.0, 255.0]
#     G: [40.0, 255.0]
#     B: [4.0, 255.0]

# %%
imshow(img,bands=(2,3,0) )
# Out:
# ImageView object:
#   Display bands       :  (2, 3, 0)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [4.0, 255.0]
#     G: [12.0, 255.0]
#     B: [40.0, 255.0]

# %% [markdown]
# GDAL

# %%
from osgeo import gdal 
import numpy as np

# %%
img2 = gdal.Open('/content/drive/MyDrive/++PESSOAL/Cursos/Mestrado/Curso_PDI_Python/Lendo e plotando/L71221071_07120010720_DN.tif')

# %%
print(img2)
# Out:
# None

# %%
img3 = img2.ReadAsArray()

# %%
imshow(img3)
# Out:
# ImageView object:
#   Display bands       :  [0, 760.0, 1519]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [12.0, 255.0]
#     G: [10.0, 255.0]
#     B: [255.0, 255.0]

# %% [markdown]
# Não leu porque acha que é uma linha.

# %%
imshow(img3[:,:,3])
# Out:
# ImageView object:
#   Display bands       :  [0]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [22.0, 255.0]
#     G: [22.0, 255.0]
#     B: [22.0, 255.0]

# %% [markdown]
# Precisa verificar o shape

# %%
img3.shape
# Out:
# (6, 1233, 1520)

# %% [markdown]
# Obs.: As bandas estão invertidas com linha e colunas

# %%
imshow(img3[3,:,:])
# Out:
# ImageView object:
#   Display bands       :  [0]
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [12.0, 255.0]
#     G: [12.0, 255.0]
#     B: [12.0, 255.0]
